# %% [markdown]
# <a href="https://colab.research.google.com/github/m37335/kanagawa-exam/blob/master/%E3%80%90%E8%8B%B1%E8%AA%9E%E3%80%91%E7%A5%9E%E5%A5%88%E5%B7%9D%E5%85%A5%E8%A9%A6%E5%95%8F%EF%BC%92%E9%81%A9%E8%AA%9E%E8%A3%9C%E5%85%85%E5%88%86%E6%9E%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **【英語】神奈川入試問２適語補充の分析**
# 自然言語処理の手法であるBERTを用いて、解答の予測を行う。
# 分析にあたっては、単語の分割を行うTokenizeはStanford大学が開発したStanzaを用いた。

# %% [markdown]
# # **ライブラリのインストール**

# %%
# !pip install transformers
# !pip install stanza
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/d8/b2/57495b5309f09fa501866e225c84532d1fd89536ea62406b2181933fb418/transformers-4.5.1-py3-none-any.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 24.6MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/ae/04/5b870f26a858552025a62f1649c20d29d2672c02ff3c3fb4c688ca46467a/tokenizers-0.10.2-cp37-cp37m-manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 53.4MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (3.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 54.2MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Installing collected packages: tokenizers, sacremoses, transformers
# Successfully installed sacremoses-0.0.45 tokenizers-0.10.2 transformers-4.5.1
# Collecting stanza
#   Downloading https://files.pythonhosted.org/packages/50/ae/a70a58ce6b4e2daad538688806ee0f238dbe601954582a74ea57cde6c532/stanza-1.2-py3-none-any.whl (282kB)
#      |████████████████████████████████| 286kB 20.1MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from stanza) (4.41.1)
# Requirement already satisfied: torch>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from stanza) (1.8.1+cu101)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from stanza) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from stanza) (1.19.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.7/dist-packages (from stanza) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->stanza) (2020.12.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (56.0.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.7/dist-packages (from protobuf->stanza) (1.15.0)
# Installing collected packages: stanza
# Successfully installed stanza-1.2

# %%
# pytorch
import torch
from transformers import BertTokenizer, BertForMaskedLM
# stanza
import stanza
stanza.download('en') # download English model
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.2.0.json: 128kB [00:00, 17.2MB/s]
# 2021-05-03 21:14:23 INFO: Downloading default packages for language: en (English)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.0/en/default.zip: 100%|██████████| 411M/411M [01:13<00:00, 5.59MB/s]
# 2021-05-03 21:15:43 INFO: Finished downloading models and saved to /root/stanza_resources.

# %% [markdown]
# ## **問２適語補充問題のインポートとデータフレームに変換**

# %%
import pandas as pd
allSentence_df = pd.read_csv('https://raw.githubusercontent.com/m37335/kanagawa-exam/master/data/kanagawaPart2.csv')

# %%
allSentence_df
# Out:
#     year  ...                                           sentence
# 0   2009  ...  Tom, a high school student from the U.S.A., ca...
# 1   2009  ...  When he was in his country, he studied Japanes...
# 2   2009  ...             So he can speak Japanese a little now.
# 3   2009  ...    For example, Japanese songs, movies, and books.
# 4   2010  ...  He lived in America for nine years and returne...
# 5   2010  ...  He speaks English well and is also good at usi...
# 6   2010  ...  Last Friday, Ryota talked with one of his Amer...
# 7   2010  ...  His American friends are going to come to Japa...
# 8   2011  ...          Mt.Fuji is the highest mountain in Japan.
# 9   2011  ...  Many people climb this mountain during the sum...
# 10  2011  ...  We left Aika's house yesterday and stayed at t...
# 11  2011  ...                                     I'm not tired.
# 12  2012  ...  When I was thirteen years old, I went camping ...
# 13  2012  ...                       We stayed there for a night.
# 14  2012  ...  Before I went, I didn't think camping was fun ...
# 15  2012  ...  But I enjoyed cooking outside, talking with my...
# 16  2013  ...            August is a good month for enjoying it.
# 17  2013  ...                 Mine is a blue one with a rainbow.
# 18  2014  ...  When I sang songs, the children began to sing ...
# 19  2014  ...  I like singing songs and playing the guitar, s...
# 20  2015  ...                          Tell me about your dream.
# 21  2015  ...  In the future, I want to learn a lot of foreig...
# 22  2015  ...  I'm always happy when I receive letters from m...
# 23  2016  ...         She said she wanted to come next Thursday.
# 24  2016  ...                    So the next day will be better.
# 25  2016  ...  She often taught me how to make cakes when I w...
# 26  2017  ...        I bought it at a new shop near the station.
# 27  2017  ...           Kate, would you like something to drink?
# 28  2017  ...                                 I am very thirsty.
# 29  2018  ...  I'm learning about traditional Japanese events...
# 30  2018  ...                          Do you have a dictionary?
# 31  2018  ...    This will be very useful to finish my homework.
# 32  2019  ...  Yes, I was born in China and I lived there unt...
# 33  2019  ...  For example, we played soccer, baseball, and g...
# 34  2019  ...  We still continue to send e-mails in Chinese t...
# 35  2020  ...  Lions kill and eat large animals, so I'm afrai...
# 36  2020  ...  So, I believe they are the strongest of all th...
# 37  2020  ...  I'm sure you'll be a good musician because you...
#
# [38 rows x 5 columns]

# %% [markdown]
# ## **Stanzaを用いてTokenに分割**
# 分割したTokenはリストに追加し、DataFrameに変換。
# その際、データの'sentence'のみ利用する。

# %%
nlp = stanza.Pipeline(processors='tokenize,mwt,pos,lemma', use_gpu=True)
stanza_token = []

for df_sentence in allSentence_df.sentence:
  doc = nlp(df_sentence)
  for sentence in doc.sentences:
    tmp_token = []
    for word in sentence.words:
      tmp_token.append(word.text)
    tmp_token.insert(0, "[CLS]")
    tmp_token.append("[SEP]")
    
    stanza_token.append(tmp_token)

#print(stanza_token)
stanza_token_df = pd.DataFrame(stanza_token)
# Out:
# 2021-05-03 21:26:09 WARNING: Can not find mwt: default from official model list. Ignoring it.
# 2021-05-03 21:26:09 INFO: Loading these models for language: en (English):
# ========================
# | Processor | Package  |
# ------------------------
# | tokenize  | combined |
# | pos       | combined |
# | lemma     | combined |
# ========================
#
# 2021-05-03 21:26:09 INFO: Use device: gpu
# 2021-05-03 21:26:09 INFO: Loading: tokenize
# 2021-05-03 21:26:09 INFO: Loading: pos
# 2021-05-03 21:26:09 INFO: Loading: lemma
# 2021-05-03 21:26:09 INFO: Done loading processors!

# %%
stanza_token_df
# Out:
#        0       1         2         3   ...         19        20     21     22
# 0   [CLS]     Tom         ,         a  ...       None      None   None   None
# 1   [CLS]    When        he       was  ...       None      None   None   None
# 2   [CLS]      So        he       can  ...       None      None   None   None
# 3   [CLS]     For   example         ,  ...       None      None   None   None
# 4   [CLS]      He     lived        in  ...      [SEP]      None   None   None
# 5   [CLS]      He    speaks   English  ...       None      None   None   None
# 6   [CLS]    Last    Friday         ,  ...          .     [SEP]   None   None
# 7   [CLS]     His  American   friends  ...       None      None   None   None
# 8   [CLS]     Mt.      Fuji        is  ...       None      None   None   None
# 9   [CLS]    Many    people     climb  ...       None      None   None   None
# 10  [CLS]      We      left      Aika  ...      [SEP]      None   None   None
# 11  [CLS]       I        'm       not  ...       None      None   None   None
# 12  [CLS]    When         I       was  ...       None      None   None   None
# 13  [CLS]      We    stayed     there  ...       None      None   None   None
# 14  [CLS]  Before         I      went  ...        the  mountain      .  [SEP]
# 15  [CLS]     But         I   enjoyed  ...       None      None   None   None
# 16  [CLS]  August        is         a  ...       None      None   None   None
# 17  [CLS]    Mine        is         a  ...       None      None   None   None
# 18  [CLS]    When         I      sang  ...       None      None   None   None
# 19  [CLS]       I      like   singing  ...       None      None   None   None
# 20  [CLS]    Tell        me     about  ...       None      None   None   None
# 21  [CLS]      In       the    future  ...  countries         .  [SEP]   None
# 22  [CLS]       I        'm    always  ...       None      None   None   None
# 23  [CLS]     She      said       she  ...       None      None   None   None
# 24  [CLS]      So       the      next  ...       None      None   None   None
# 25  [CLS]     She     often    taught  ...       None      None   None   None
# 26  [CLS]       I    bought        it  ...       None      None   None   None
# 27  [CLS]    Kate         ,     would  ...       None      None   None   None
# 28  [CLS]       I        am      very  ...       None      None   None   None
# 29  [CLS]       I        'm  learning  ...       None      None   None   None
# 30  [CLS]      Do       you      have  ...       None      None   None   None
# 31  [CLS]    This      will        be  ...       None      None   None   None
# 32  [CLS]     Yes         ,         I  ...      [SEP]      None   None   None
# 33  [CLS]     For   example         ,  ...       None      None   None   None
# 34  [CLS]      We     still  continue  ...       None      None   None   None
# 35  [CLS]   Lions      kill       and  ...       None      None   None   None
# 36  [CLS]      So         ,         I  ...       None      None   None   None
# 37  [CLS]       I        'm      sure  ...       None      None   None   None
#
# [38 rows x 23 columns]

# %%
# allSentence_dfとstanza_token_dfを結合し、一つのDataFrameにする。
df_concat = pd.concat([allSentence_df, stanza_token_df], axis=1)

# %%
df_concat
# Out:
#     year  s_id  question  ...        20     21     22
# 0   2009     1         1  ...      None   None   None
# 1   2009     2         2  ...      None   None   None
# 2   2009     3         3  ...      None   None   None
# 3   2009     5         4  ...      None   None   None
# 4   2010     2         1  ...      None   None   None
# 5   2010     3         2  ...      None   None   None
# 6   2010     4         3  ...     [SEP]   None   None
# 7   2010     5         4  ...      None   None   None
# 8   2011     4         1  ...      None   None   None
# 9   2011     5         2  ...      None   None   None
# 10  2011     8         3  ...      None   None   None
# 11  2011    10         4  ...      None   None   None
# 12  2012     1         1  ...      None   None   None
# 13  2012     2         2  ...      None   None   None
# 14  2012     6         3  ...  mountain      .  [SEP]
# 15  2012     7         4  ...      None   None   None
# 16  2013     4         1  ...      None   None   None
# 17  2013     6         2  ...      None   None   None
# 18  2014     2         1  ...      None   None   None
# 19  2014     5         2  ...      None   None   None
# 20  2015     2         1  ...      None   None   None
# 21  2015     3         2  ...         .  [SEP]   None
# 22  2015    11         3  ...      None   None   None
# 23  2016     2         1  ...      None   None   None
# 24  2016     4         2  ...      None   None   None
# 25  2016     9         3  ...      None   None   None
# 26  2017     6         1  ...      None   None   None
# 27  2017     9         2  ...      None   None   None
# 28  2017    12         3  ...      None   None   None
# 29  2018     5         1  ...      None   None   None
# 30  2018     9         2  ...      None   None   None
# 31  2018    13         3  ...      None   None   None
# 32  2019     1         1  ...      None   None   None
# 33  2019     4         2  ...      None   None   None
# 34  2019     8         3  ...      None   None   None
# 35  2020     5         1  ...      None   None   None
# 36  2020     9         2  ...      None   None   None
# 37  2020    12         3  ...      None   None   None
#
# [38 rows x 28 columns]

# %% [markdown]
# ### **問題部分をMASKにする**

# %%
# それぞれの問題部分の単語をIDで指定する
mask_id = pd.Series([11, 6, 7, 2, 6, 12, 2, 14, 5, 6, 6, 4, 4, 6, 16, 16, 5, 1, 8, 16, 5, 12, 7, 8, 7, 3, 2, 3, 4, 5, 5, 5, 5, 2, 3, 11, 8, 15], name="mask_id")

# %%
# 結合
df = pd.concat([df_concat, mask_id], axis=1)

# %%
df
# Out:
#     year  s_id  question  ...     21     22 mask_id
# 0   2009     1         1  ...   None   None      11
# 1   2009     2         2  ...   None   None       6
# 2   2009     3         3  ...   None   None       7
# 3   2009     5         4  ...   None   None       2
# 4   2010     2         1  ...   None   None       6
# 5   2010     3         2  ...   None   None      12
# 6   2010     4         3  ...   None   None       2
# 7   2010     5         4  ...   None   None      14
# 8   2011     4         1  ...   None   None       5
# 9   2011     5         2  ...   None   None       6
# 10  2011     8         3  ...   None   None       6
# 11  2011    10         4  ...   None   None       4
# 12  2012     1         1  ...   None   None       4
# 13  2012     2         2  ...   None   None       6
# 14  2012     6         3  ...      .  [SEP]      16
# 15  2012     7         4  ...   None   None      16
# 16  2013     4         1  ...   None   None       5
# 17  2013     6         2  ...   None   None       1
# 18  2014     2         1  ...   None   None       8
# 19  2014     5         2  ...   None   None      16
# 20  2015     2         1  ...   None   None       5
# 21  2015     3         2  ...  [SEP]   None      12
# 22  2015    11         3  ...   None   None       7
# 23  2016     2         1  ...   None   None       8
# 24  2016     4         2  ...   None   None       7
# 25  2016     9         3  ...   None   None       3
# 26  2017     6         1  ...   None   None       2
# 27  2017     9         2  ...   None   None       3
# 28  2017    12         3  ...   None   None       4
# 29  2018     5         1  ...   None   None       5
# 30  2018     9         2  ...   None   None       5
# 31  2018    13         3  ...   None   None       5
# 32  2019     1         1  ...   None   None       5
# 33  2019     4         2  ...   None   None       2
# 34  2019     8         3  ...   None   None       3
# 35  2020     5         1  ...   None   None      11
# 36  2020     9         2  ...   None   None       8
# 37  2020    12         3  ...   None   None      15
#
# [38 rows x 29 columns]

# %% [markdown]
# ## **単語のMASK化**

# %%
# 単語の分割の設定
tokenizer = BertTokenizer.from_pretrained("bert-base-cased")
# マスクの設定
msk_model = BertForMaskedLM.from_pretrained("bert-base-cased")
# GPUを使用
msk_model.cuda()
msk_model.eval()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=29.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435797.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=570.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435779157.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# BertForMaskedLM(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(28996, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (cls): BertOnlyMLMHead(
#     (predictions): BertLMPredictionHead(
#       (transform): BertPredictionHeadTransform(
#         (dense): Linear(in_features=768, out_features=768, bias=True)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       )
#       (decoder): Linear(in_features=768, out_features=28996, bias=True)
#     )
#   )
# )

# %% [markdown]
# ## **MASK化した単語をBERTを用いて予測する**

# %%
possible_answer = []

mask_id_list = df.mask_id
words = stanza_token_df.values.tolist()

for (words, mask_id) in zip(words, mask_id_list):
  # リスト内"NONE"を削除する
  words = [x for x in words if x is not None]

  # 特定の文字列をマスクに変換する
  msk_idx = mask_id
  words[msk_idx] = "[MASK]"

  #print(words)

  # tokenをidに変換
  word_ids = tokenizer.convert_tokens_to_ids(words)
  #print(word_ids)
  word_tensor = torch.tensor([word_ids])
  # print(word_tensor)
  
  # マスクした部分の予測
  x = word_tensor.cuda()
  y = msk_model(x)
  result = y[0]
  # print(result.size())
  
  _, msk_ids = torch.topk(result[0][msk_idx], k=10)
  result_words = tokenizer.convert_ids_to_tokens(msk_ids.tolist())

  possible_answer.append(result_words)
  
  # 予測した結果を出力
  print(result_words)
# Out:
# ['came', 'went', 'returned', 'comes', 'moved', 'arrived', 'traveled', 'returns', 'flew', 'goes']
# ['teens', 'twenties', 'prime', 'youth', 'childhood', 'infancy', '60s', 'hometown', '70s', '80s']
# ['lot', 'little', 'bit', 'while', 'second', 'secret', 'minute', 'ways', 'moment', 'word']
# ['example', 'instance', 'children', 'music', 'entertainment', 'television', 'sale', 'comparison', 'reference', 'them']
# ['two', 'three', 'four', 'five', 'several', 'seven', 'six', 'ten', 'eight', 'nine']
# ['wheelchair', 'cane', 'knife', 'gun', 'weapon', 'computer', 'dictionary', 'hammer', 'keyboard', 'sword']
# ['night', 'week', '##ly', 'year', 'Sunday', 'month', 'time', 'day', 'Friday', 'Monday']
# ['year', 'summer', 'week', 'day', 'time', 'weekend', 'month', 'Christmas', 'evening', 'morning']
# ['highest', 'tallest', 'largest', 'northernmost', 'lowest', 'southernmost', 'smallest', 'deepest', 'Highest', 'longest']
# ['in', 'during', 'over', 'for', 'throughout', 'through', 'on', 'around', 'into', 'every']
# [',', '...', 'first', 'yesterday', '[UNK]', 'behind', ']', 'early', '-', 'again']
# ['you', 'here', 'to', 'me', 'know', 'yet', 'now', 'it', 'that', 'sure']
# ['five', 'eight', 'six', 'three', 'ten', 'four', 'seven', 'nine', 'twelve', 'two']
# ['while', 'week', 'bit', 'time', 'minute', 'month', 'moment', 'year', 'day', 'second']
# ['watch', 'see', 'do', 'have', 'watching', 'hear', 'get', 'make', 'Watch', 'enjoy']
# ['somewhere', 'together', 'outside', 'nearby', 'alone', 'overnight', 'bed', 'again', 'tonight', 'there']
# ['time', 'month', 'day', 'year', 'date', 'week', 'season', 'period', 'night', 'one']
# ['It', 'There', 'This', 'it', 'One', 'She', 'He', 'Another', 'Here', 'Mine']
# ['began', 'used', 'started', 'had', 'wanted', 'liked', 'loved', 'learned', 'came', 'seemed']
# ['musician', 'singer', 'songwriter', 'drummer', 'guitarist', 'writer', 'vocalist', 'composer', 'poet', 'performer']
# ['family', 'childhood', 'father', 'mother', 'parents', 'life', 'mom', 'grandmother', 'dad', 'brother']
# ['foreign', 'different', 'new', 'European', 'other', 'the', 'world', 'African', 'more', 'these']
# ['receive', 'get', 'received', 'read', 'have', 'got', 'hear', 'find', 'write', 'see']
# ['time', 'week', 'year', 'month', 'weekend', 'summer', 'day', 'Saturday', 'night', 'Sunday']
# ['different', 'easier', 'better', 'tomorrow', 'over', 'easy', 'mine', 'perfect', 'free', 'today']
# ['taught', 'showed', 'told', 'teaches', 'shows', 'shown', 'asked', 'instructed', 'reminded', 'teach']
# ['bought', 'found', 'purchased', 'buy', 'sold', 'left', 'got', 'rented', 'sell', 'saw']
# ['would', 'Would', 'could', 'do', 'will', 'did', 'might', 'can', 'if', 'should']
# ['sorry', 'tired', 'happy', 'glad', 'pleased', 'hungry', 'nervous', 'disappointed', 'grateful', 'afraid']
# ['the', 'big', 'traditional', 'other', 'important', 'various', 'major', 'upcoming', 'new', 'some']
# ['phone', 'plan', 'car', 'name', 'key', 'gun', 'choice', 'boyfriend', 'number', 'girlfriend']
# ['good', 'helpful', 'nice', 'hard', 'important', 'difficult', 'interesting', 'easy', 'fun', 'useful']
# ['born', 'raised', 'educated', 'living', 'based', 'trained', 'buried', 'originally', 'from', 'Born']
# ['years', 'us', 'school', 'example', 'them', 'months', 'fun', 'me', 'hours', 'instance']
# ['have', 'need', 'want', 'had', 'used', 'continue', 'wanted', 'refuse', 'try', 'wish']
# ['speak', 'think', 'know', '[UNK]', 'fear', 'eat', 'talk', 'speaks', 'Think', 'because']
# ['ancestors', 'bones', 'parents', 'brains', 'spirits', 'mother', 'eyes', 'source', 'origin', 'heads']
# ['voice', 'sound', 'soul', 'heart', 'music', 'face', 'life', 'mind', 'wife', 'body']

# %% [markdown]
# ## **BERTを用いて予測された解答**

# %%
# 予測された単語リストをDataFrameに変換
result_words_df = pd.DataFrame(possible_answer)
# 新たに作成したDataFrameと元々のDataFrameを結合
possibleAnswer_df = pd.concat([allSentence_df, result_words_df], axis=1)
# 不要な列を削除
possibleAnswer_df = possibleAnswer_df.drop(columns='sentence', axis=1)

# %%
possibleAnswer_df
# Out:
#     year  s_id  question  ...             7          8           9
# 0   2009     1         1  ...       returns       flew        goes
# 1   2009     2         2  ...      hometown        70s         80s
# 2   2009     3         3  ...          ways     moment        word
# 3   2009     5         4  ...    comparison  reference        them
# 4   2010     2         1  ...           ten      eight        nine
# 5   2010     3         2  ...        hammer   keyboard       sword
# 6   2010     4         3  ...           day     Friday      Monday
# 7   2010     5         4  ...     Christmas    evening     morning
# 8   2011     4         1  ...       deepest    Highest     longest
# 9   2011     5         2  ...        around       into       every
# 10  2011     8         3  ...         early          -       again
# 11  2011    10         4  ...            it       that        sure
# 12  2012     1         1  ...          nine     twelve         two
# 13  2012     2         2  ...          year        day      second
# 14  2012     6         3  ...          make      Watch       enjoy
# 15  2012     7         4  ...         again    tonight       there
# 16  2013     4         1  ...        period      night         one
# 17  2013     6         2  ...       Another       Here        Mine
# 18  2014     2         1  ...       learned       came      seemed
# 19  2014     5         2  ...      composer       poet   performer
# 20  2015     2         1  ...   grandmother        dad     brother
# 21  2015     3         2  ...       African       more       these
# 22  2015    11         3  ...          find      write         see
# 23  2016     2         1  ...      Saturday      night      Sunday
# 24  2016     4         2  ...       perfect       free       today
# 25  2016     9         3  ...    instructed   reminded       teach
# 26  2017     6         1  ...        rented       sell         saw
# 27  2017     9         2  ...           can         if      should
# 28  2017    12         3  ...  disappointed   grateful      afraid
# 29  2018     5         1  ...      upcoming        new        some
# 30  2018     9         2  ...     boyfriend     number  girlfriend
# 31  2018    13         3  ...          easy        fun      useful
# 32  2019     1         1  ...    originally       from        Born
# 33  2019     4         2  ...            me      hours    instance
# 34  2019     8         3  ...        refuse        try        wish
# 35  2020     5         1  ...        speaks      Think     because
# 36  2020     9         2  ...        source     origin       heads
# 37  2020    12         3  ...          mind       wife        body
#
# [38 rows x 14 columns]
